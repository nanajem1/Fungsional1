# %% [markdown]
# <a href="https://colab.research.google.com/github/nanajem1/Fungsional1/blob/main/fungsional5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# xpoints = np.array([0, 6])
# ypoints = np.array([0, 250])

# modifikasi

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# xpoints = np.array([1, 8, 10])
# ypoints = np.array([3, 10, 5])

# plt.figure(figsize=(5,5))
# plt.plot(xpoints, ypoints, color="red")

# plt.xlim([0, 16])
# plt.ylim([0, 16])
# plt.show()

# modifikasi
xpoints = np.array([1, 8, 10])
ypoints = np.array([3, 10, 5])

plt.figure(figsize=(5,5))

plt.plot(xpoints, ypoints, marker="^", color="green", linestyle="dashed", linewidth=2, markersize=8)
plt.xlim([0, 16])
plt.ylim([0, 16])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# y1 = np.array([3, 8, 1, 10])
# y2 = np.array([6, 2, 7, 11])

# #membuat plot untuk garis y1 dan y2
# plt.plot(y1, label='Garis 1')
# plt.plot(y2, label='Garis 2')

# #menambahkan judul danlabel sumbu
# plt.title('Plot Dua Garis')
# plt.xlabel('Nilai x')
# plt.ylabel('Nilai y')

# #menambahkan keterangan (legend)
# plt.legend()
# plt.show()


# modifikasi

grafik1 = np.array([1, 5, 7, 2])
grafik2 = np.array([5, 2, 6, 10])
grafik3 = np.array([8, 2, 4, 7])

plt.plot(grafik1, label="Grafik A", marker="H", color="red", ls="dotted")
plt.plot(grafik2, label="Grafik B", color="yellow")
plt.plot(grafik3, label="Grafik C", marker="^", ls="dotted", color="blue")

plt.title("Plot Tiga Garis")
plt.xlabel("Nilai x")
plt.ylabel("Nilai y")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 7, 2, 8, 5]

# plt.scatter(x, y)
plt.scatter(x, y, label="sX", marker="*", color="red")
plt.show()

# %%
from matplotlib import pyplot as plt
from numpy.random import normal
from numpy import mean, std
from scipy.stats import norm


# percobaan 1
sample = normal(loc=50, scale=5, size=1000)
plt.figure(figsize=(5,4))
plt.hist(sample, bins=10, density=True)
plt.show()

# percobaan 2
sample_mean = mean(sample)
sample_std = std(sample)
print("Mean=%.3f \nStandard Deviation=%.3f" % (sample_mean, sample_std))

# percobaan 3
dist = norm(sample_mean, sample_std)
dist

# percobaan 4
values = [value for value in range(30, 70)]
probabilitas = [dist.pdf(value) for value in values]
probabilitas

plt.hist(sample, bins=10, density=True)
plt.plot(values, probabilitas)
plt.show()
# Out:
# Mean=49.847
# Standard Deviation=5.095
